# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
#   <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
#   <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
#   <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
#   Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
#   Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.
#
# **``NOTE:``**  However, you are free to create your own style. You do NOT have to stick to the steps above. We, the DA & DV instructors, recommend you study each part separately to create a source notebook for each part title for your further studies.

# %% [markdown]
# #  PART- 1 `( Data Cleaning )`

# %%
import numpy as np
import pandas as pd
from skimpy import clean_columns

import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import re

#!pip install plotly
import plotly 
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import iplot
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

# The maximum width in characters of a column
pd.set_option('display.max_colwidth', 80)

# To display maximum columns
pd.set_option('display.max_columns', None)

# To display maximum rows
pd.set_option('display.max_rows', 100)

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <a id="3"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4; font-weight:bold; text-transform:capitalize;">Recognizing and Understanding Data</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# 01. Reading the Data from File  (Dosyadan Veri Okuma)
# 02. Try to understand what the data looks like(Verilerin neye benzediğini anlamaya çalışın)
# 03. Examining the Data   (Verilerin İncelenmesi)
# 04. Fixing a data type   (Bir veri türünü düzeltme)
# 05. Combining object columns   (Nesne sütunlarını birleştirme)

# %% [markdown]
# ## Reading the Data from File

# %%
autoscout_orijin=pd.read_json("scout_car.json", lines=True)
df=autoscout_orijin.copy()
df.head(3).T
# Out:
#                                                                                                              0  \
# url                            https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon...
# make_model                                                                                             Audi A1
# short_description                                                  Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                                                               Sedans
# price                                                                                                    15770
# vat                                                                                             VAT deductible
# km                                                                                                   56,013 km
# ...

# %% [markdown]
# ## Try to understand what the data looks like
# - Check the head, shape, data-types of the features.(Özelliklerin başını, şeklini, veri türlerini kontrol edin)
# - Check if there are some dublicate rows or not. If there are, then drop them.(Yinelenen satır kontrolü,varsa düşülmesi)
# - Check the statistical values of features.(Özelliklerin istatistiksel değerlerini kontrol edin)
# - Basically check the missing values. (NaN, None)(Temel olarak eksik değerleri kontrol edin. (NaN, Yok))
# - If needed, rename the columns' names for easy use.(Gerekirse, kolay kullanım için sütunların adlarını yeniden adlandırın.)

# %% [markdown]
# ### Check the head, shape, data-types of the features.

# %%
df.shape
# Out:
# (15919, 54)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
# ...

# %% [markdown]
# ### Check if there are some dublicate rows or not. If there are, then drop them.

# %%
# error rising because of list type
df.duplicated
# Out:
# <bound method DataFrame.duplicated of                                                                                    url  \
# 0      https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon...
# 1      https://www.autoscout24.com//offers/audi-a1-1-8-tfsi-sport-gasoline-red-b254...
# 2      https://www.autoscout24.com//offers/audi-a1-sportback-1-6-tdi-s-tronic-einpa...
# 3      https://www.autoscout24.com//offers/audi-a1-1-4-tdi-design-s-tronic-diesel-b...
# 4      https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-s-lin...
# ...                                                                                ...
# 15914  https://www.autoscout24.com//offers/renault-espace-blue-dci-200cv-edc-execut...
# 15915  https://www.autoscout24.com//offers/renault-espace-tce-225-edc-gpf-lim-delux...
# 15916  https://www.autoscout24.com//offers/renault-espace-blue-dci-200-edc-initiale...
# ...

# %% [markdown]
# ### Check the statistical values of features.

# %%
df.describe().T
# Out:
#          count          mean          std   min      25%      50%      75%  \
# price  15919.0  18019.896727  7386.169409  13.0  12850.0  16900.0  21900.0
# kW         0.0           NaN          NaN   NaN      NaN      NaN      NaN
#
#            max
# price  74600.0
# kW         NaN

# %%
#df.describe(include='O').T

# %%
# all values in the "kW" column are null. Because of that it will be dropped
# all values in the "null" column are an empty list. because of that it will be dropped
df.drop(columns=["kW","null"],inplace=True)

# %% [markdown]
# ### Basically check the missing values. (NaN, None)-(isna(), mean())

# %%
df.isna().sum()
# Out:
# url                                  0
# make_model                           0
# short_description                   46
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                         0
# prev_owner                        6828
# hp                                   0
# Type                                 2
# Previous Owners                   6640
# Next Inspection                  12384
# Inspection new                   11987
# Warranty                          5420
# Full Service                      7704
# Non-smoking Vehicle               8742
# Make                                 0
# Model                                0
# Offer Number                      3175
# First Registration                1597
# Body Color                         597
# Paint Type                        5772
# Body Color Original               3759
# ...

# %%
df.isna().sum()*100/ df.shape[0]  #for percent
#df.isna().sum().mean()*100
# Out:
# url                               0.000000
# make_model                        0.000000
# short_description                 0.288963
# body_type                         0.376908
# price                             0.000000
# vat                              28.349771
# km                                0.000000
# registration                      0.000000
# prev_owner                       42.892141
# hp                                0.000000
# Type                              0.012564
# Previous Owners                  41.711163
# Next Inspection                  77.793831
# Inspection new                   75.299956
# Warranty                         34.047365
# Full Service                     48.395000
# Non-smoking Vehicle              54.915510
# Make                              0.000000
# Model                             0.000000
# Offer Number                     19.944720
# First Registration               10.032037
# Body Color                        3.750236
# ...

# %% [markdown]
# ### If needed, rename the columns' names for easy use.

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'hp', 'Type', 'Previous Owners',
#        'Next Inspection', 'Inspection new', 'Warranty', 'Full Service',
#        'Non-smoking Vehicle', 'Make', 'Model', 'Offer Number',
#        'First Registration', 'Body Color', 'Paint Type', 'Body Color Original',
#        'Upholstery', 'Body', 'Nr. of Doors', 'Nr. of Seats', 'Model Code',
#        'Gearing Type', 'Displacement', 'Cylinders', 'Weight', 'Drive chain',
#        'Fuel', 'Consumption', 'CO2 Emission', 'Emission Class',
#        '\nComfort & Convenience\n', '\nEntertainment & Media\n', '\nExtras\n',
#        '\nSafety & Security\n', 'description', 'Emission Label', 'Gears',
#        'Country version', 'Electricity consumption', 'Last Service Date',
#        'Other Fuel Types', 'Availability', 'Last Timing Belt Service Date',
#        'Available from'],
#       dtype='object')

# %%
# cleaning column names using skimpy clean_columns method
df = clean_columns(df)
# Out:
# 41 column names have been cleaned

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'hp', 'type', 'previous_owners',
#        'next_inspection', 'inspection_new', 'warranty', 'full_service',
#        'non_smoking_vehicle', 'make', 'model', 'offer_number',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'upholstery', 'body', 'nr_of_doors', 'nr_of_seats', 'model_code',
#        'gearing_type', 'displacement', 'cylinders', 'weight', 'drive_chain',
#        'fuel', 'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'electricity_consumption', 'last_service_date',
#        'other_fuel_types', 'availability', 'last_timing_belt_service_date',
#        'available_from'],
#       dtype='object')

# %%
# df['Comfort_Convenience'] =df['\nComfort & Convenience\n']    #farklı bir yaklşım
# df['Entertaintment_Media'] = df['\nEntertainment & Media\n']
# df['Extras'] = df['\nExtras\n']
# df['Safety_Security'] = df['\nSafety & Security\n']

# %%
# drop_columns = ['\nComfort & Convenience\n', '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n']
# drop_columns
#df.drop(drop_columns, axis = 1, inplace = True)

# %% [markdown]
# ## Examining the Data
# - Look at the counts of columns that have OBJECT datatype           (OBJECT veri tipine sahip sütunların sayısına bakın)
# - Assign the Columns (Features) of object data type as** **`"object_col"`**(Nesne veri türünün Sütunlarını (Özellikleri)** **`"object_col"`** olarak atayın)
# - Detect strange values apart from the NaN Values.(isin(),Count(),Sum(),Any())(NaN Değerleri dışındaki garip değerleri tespit edin.(isin(),Count(),Sum(),Any()))

# %% [markdown]
# ### Look at the counts of columns that have OBJECT datatype

# %%
df.columns[df.dtypes == 'O']
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'vat', 'km',
#        'registration', 'prev_owner', 'hp', 'type', 'previous_owners',
#        'next_inspection', 'inspection_new', 'warranty', 'full_service',
#        'non_smoking_vehicle', 'make', 'model', 'offer_number',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'upholstery', 'body', 'nr_of_doors', 'nr_of_seats', 'model_code',
#        'gearing_type', 'displacement', 'cylinders', 'weight', 'drive_chain',
#        'fuel', 'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'electricity_consumption', 'last_service_date',
#        'other_fuel_types', 'availability', 'last_timing_belt_service_date',
#        'available_from'],
#       dtype='object')

# %% [markdown]
# ### Assign the Columns (Features) of object data type as** **``"object_col"``

# %%
#df.columns[df.dtypes == 'O']
# df.select_dtypes('O').columns
#df.describe(include='O').columns

object_col = df.select_dtypes('O').sort_index(axis=1).columns
object_col
# Out:
# Index(['availability', 'available_from', 'body', 'body_color',
#        'body_color_original', 'body_type', 'co_2_emission',
#        'comfort_&_convenience', 'consumption', 'country_version', 'cylinders',
#        'description', 'displacement', 'drive_chain', 'electricity_consumption',
#        'emission_class', 'emission_label', 'entertainment_&_media', 'extras',
#        'first_registration', 'fuel', 'full_service', 'gearing_type', 'gears',
#        'hp', 'inspection_new', 'km', 'last_service_date',
#        'last_timing_belt_service_date', 'make', 'make_model', 'model',
#        'model_code', 'next_inspection', 'non_smoking_vehicle', 'nr_of_doors',
#        'nr_of_seats', 'offer_number', 'other_fuel_types', 'paint_type',
#        'prev_owner', 'previous_owners', 'registration', 'safety_&_security',
#        'short_description', 'type', 'upholstery', 'url', 'vat', 'warranty',
#        'weight'],
#       dtype='object')

# %%
# Convert List type object to str type all Column(Liste türü nesnesini  tüm kolonlarda str türüne dönüştürün)
df = df.applymap(lambda x: ','.join(map(str, x)) if isinstance(x, list) else x)
df.head(2)
# Out:
#                                                                                url  \
# 0  https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon...
# 1  https://www.autoscout24.com//offers/audi-a1-1-8-tfsi-sport-gasoline-red-b254...
#
#   make_model                            short_description body_type  price  \
# 0    Audi A1  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1    Audi A1                               1.8 TFSI sport    Sedans  14500
#
#                 vat         km registration         prev_owner      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners   66 kW
# 1  Price negotiable  80,000 km      03/2017               None  141 kW
#
#                                  type previous_owners  \
# 0  ,Used,,Diesel (Particulate Filter)           \n2\n
# 1                     ,Used,,Gasoline             NaN
#
#                       next_inspection      inspection_new  \
# ...

# %%
def first_look(col):
    print('column name : ', col)
    print('--------------------------------')
    print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
    print('Num_of_Nulls   : ', df[col].isnull().sum())
    print('Num_of_Uniques : ', df[col].nunique())
    print("Value_counts :\n",df[col].value_counts(dropna = False))
    print()
    print("Value_counts with sort index :\n",df[col].value_counts(dropna = False).sort_index())
    print("##"*20)
    print()

# %%
for col in object_col:
    first_look(col)
# Out:
# column name :  availability
# --------------------------------
# Per_of_Nulls   :  % 96.01
# Num_of_Nulls   :  15284
# Num_of_Uniques :  15
# Value_counts :
#  NaN                              15284
# \nin 90 days from ordering\n       196
# \nin 120 days from ordering\n      182
# \nin 1 day from ordering\n          51
# \nin 5 days from ordering\n         35
# \nin 3 days from ordering\n         35
# \nin 180 days from ordering\n       24
# \nin 14 days from ordering\n        24
# \nin 7 days from ordering\n         20
# \nin 150 days from ordering\n       18
# \nin 2 days from ordering\n         16
# \nin 60 days from ordering\n        13
# \nin 42 days from ordering\n        10
# \nin 21 days from ordering\n         8
# \nin 4 days from ordering\n          2
# \nin 6 days from ordering\n          1
# Name: availability, dtype: int64
#
# Value_counts with sort index :
#  \nin 1 day from ordering\n          51
# \nin 120 days from ordering\n      182
# ...

# %%
##checking duplicated rows

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# str.replace - Strip strange values apart from beginning and end(Garip değerleri başlangıç ve bitişten ayırın)
# You would use dtypes with a DataFrame to get the dtype for each column/Series.(Or Numpy dtype)
        #(Her sütun/Seri için dtype'ı almak için DataFrame ile dtypes kullanırsınız.(Veya Numpy dtype))
          
# df = df.select_dtypes(include="O").apply(lambda x: x.str.replace(",?\n,?",""))
# df.sample(10)
df=df.apply(lambda x: x.str.replace(",?\n,?", "") if x.dtype =='O' else x)
df.head()
# Out:
#                                                                                url  \
# 0  https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon...
# 1  https://www.autoscout24.com//offers/audi-a1-1-8-tfsi-sport-gasoline-red-b254...
# 2  https://www.autoscout24.com//offers/audi-a1-sportback-1-6-tdi-s-tronic-einpa...
# 3  https://www.autoscout24.com//offers/audi-a1-1-4-tdi-design-s-tronic-diesel-b...
# 4  https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-s-lin...
#
#   make_model                                   short_description body_type  \
# 0    Audi A1         Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans
# 1    Audi A1                                      1.8 TFSI sport    Sedans
# 2    Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+music    Sedans
# 3    Audi A1                             1.4 TDi Design S tronic    Sedans
# 4    Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired, Xe    Sedans
#
# ...

# %%
#2. yol olarak
# strip - Strip strange values apart from beginning and end(strip - Garip değerleri başlangıç ve bitişten ayırın)
#df = df.applymap(lambda x: x.strip("\\n\n,][ '-.") if isinstance(x, str) else x, na_action='ignore')

# %%
# Error because of list type in Column
for col in object_col:
    first_look(col)
# Out:
# column name :  availability
# --------------------------------
# Per_of_Nulls   :  % 96.01
# Num_of_Nulls   :  15284
# Num_of_Uniques :  15
# Value_counts :
#  NaN                          15284
# in 90 days from ordering       196
# in 120 days from ordering      182
# in 1 day from ordering          51
# in 5 days from ordering         35
# in 3 days from ordering         35
# in 180 days from ordering       24
# in 14 days from ordering        24
# in 7 days from ordering         20
# in 150 days from ordering       18
# in 2 days from ordering         16
# in 60 days from ordering        13
# in 42 days from ordering        10
# in 21 days from ordering         8
# in 4 days from ordering          2
# in 6 days from ordering          1
# Name: availability, dtype: int64
#
# Value_counts with sort index :
#  in 1 day from ordering          51
# in 120 days from ordering      182
# in 14 days from ordering        24
# in 150 days from ordering       18
# ...

# %%
df.shape
# Out:
# (15919, 52)

# %% [markdown]
# ### Detect strange values apart from the NaN Values.(isin(),Count(),Sum(),Any())

# %%
#display(df['consumption'].head(3))

# %%
# # erase some characters with replace methods in "consumption" column
# new_columns = ["consumption_comb","consumption_city","consumption_country"]
# df["consumption"]=df["consumption"].str.replace("\n,","")

# # split the "consumption" column
# df[new_columns]=df["consumption"].str.split(",",expand=True).loc[:,:2].applymap(lambda x : np.nan if x == "[]" or  x == "\n" else x)

# # checking values of the new columns
# print("count of null values in the comb columns\t:",len(df)-df["consumption"].str.contains("comb").sum())
# print("count of null values in the city columns\t:",len(df)-df["consumption"].str.contains("city").sum())
# print("count of null values in the country columns\t:",len(df)-df["consumption"].str.contains("country").sum())
# df[new_columns].isnull().sum()

# %%
# for i in df[new_columns]:
#     df[i] = df[i].str.extract(r"(\d*\.\d+|\d+)")
# df[new_columns].isnull().sum()

# %%
# df[['consumption', 'consumption_comb', 'consumption_city', 'consumption_country']].sample(5)

# %% [markdown]
# ## After Checking the First look Results and Descriptive values of each column

# %%
df.shape
# Out:
# (15919, 52)

# %% [markdown]
#  - to replace empty rows with np.nan(boş satırları np.nan ile değiştirmek için)
#
#  - to replace empty list with np.nan(boş listeyi np.nan ile değiştirmek için)
#
#  - to drop columns containing greater than or equal %95null values(%95 veya daha büyük boş değeriçeren sütunları bırakmak için)
#
#  - to apply data cleaning column by column.(veri temizleme sütununu sütuna uygulamak için)

# %% [markdown]
# ### Replacing empty rows with np.nan

# %%
df["non_smoking_vehicle"][df.non_smoking_vehicle.str.contains(r'^\s*$')==True] = np.nan
df["non_smoking_vehicle"].isnull().sum()
# Out:
# 12459

# %%
(df.non_smoking_vehicle.str.contains(r'^\s*$')).isnull().sum()
# Out:
# 12459

# %%
df[df.isin(['', '[],[],[]'])]= np.nan

# %%
df.isnull().sum()
# Out:
# url                                  0
# make_model                           0
# short_description                   46
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                         0
# prev_owner                        6828
# hp                                   0
# type                                 2
# previous_owners                   6640
# next_inspection                  12384
# inspection_new                   11987
# warranty                          6763
# full_service                      9689
# non_smoking_vehicle              12459
# make                                 0
# model                                0
# offer_number                      3175
# first_registration                1597
# body_color                         597
# paint_type                        5772
# body_color_original               3759
# ...

# %% [markdown]
# ### Replacing rows containing only empt list with np.nan

# %%
df.other_fuel_types.value_counts(dropna=False)
# Out:
# NaN    15919
# Name: other_fuel_types, dtype: int64

# %%
df.isin(['[],[],[]']).sum()
# Out:
# url                              0
# make_model                       0
# short_description                0
# body_type                        0
# price                            0
# vat                              0
# km                               0
# registration                     0
# prev_owner                       0
# hp                               0
# type                             0
# previous_owners                  0
# next_inspection                  0
# inspection_new                   0
# warranty                         0
# full_service                     0
# non_smoking_vehicle              0
# make                             0
# model                            0
# offer_number                     0
# first_registration               0
# body_color                       0
# paint_type                       0
# body_color_original              0
# upholstery                       0
# body                             0
# nr_of_doors                      0
# ...

# %%
df.other_fuel_types.replace(to_replace=r'\[\]', value=np.nan, regex=True).isnull().sum()
# Out:
# 15919

# %% [markdown]
# ### Drop columns containing greater than or equal %95 null values

# %%
#Columns with more than 95% null(%95 üzerinde null olan kolonlar)
print(df.shape)
for col in df.columns:
    if (df[col].isnull().sum()/df.shape[0]*100)>=95:
        print(col)
        print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
        print("-"*25)
# Out:
# (15919, 52)
# electricity_consumption
# Per_of_Nulls   :  % 99.14
# -------------------------
# last_service_date
# Per_of_Nulls   :  % 96.44
# -------------------------
# other_fuel_types
# Per_of_Nulls   :  % 100.0
# -------------------------
# availability
# Per_of_Nulls   :  % 96.01
# -------------------------
# last_timing_belt_service_date
# Per_of_Nulls   :  % 99.9
# -------------------------
# available_from
# Per_of_Nulls   :  % 98.29
# -------------------------

# %%
print(df.shape)
for col in df.columns:
    if (df[col].isnull().sum()/df.shape[0]*100)>=95:
        df.drop(col,axis=1,inplace=True)
print(df.shape)
# Out:
# (15919, 52)
# (15919, 46)

# %%
# (df.isna().sum().div(df.shape[0])*100).sort_values(ascending=False)  # alternatif null oranı bulma kodu

# %% [markdown]
# ## Column by column data cleaning

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'hp', 'type', 'previous_owners',
#        'next_inspection', 'inspection_new', 'warranty', 'full_service',
#        'non_smoking_vehicle', 'make', 'model', 'offer_number',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'upholstery', 'body', 'nr_of_doors', 'nr_of_seats', 'model_code',
#        'gearing_type', 'displacement', 'cylinders', 'weight', 'drive_chain',
#        'fuel', 'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version'],
#       dtype='object')

# %%
def get_diff_category_column(Series:pd.Series, exclude=''',/\n''', pattern=r'''[,\n]| /''', strip='''\n' "!?|.,*+-_/][\\n''', diff_value=list()):  
    diff_value.clear()
    column = Series.dropna().apply(str).str.strip(strip)
    for row in column:
        if not any(x in exclude for x in row) and row not in diff_value:
            diff_value.append(row)
        else:
            for data in map(lambda x: x.strip(strip), filter(None, re.split(pattern, row))):
                if data not in diff_value:
                    diff_value.append(data)
    return dict(enumerate(sorted(diff_value)))

# %% [markdown]
# ### url column

# %%
first_look("url")
# Out:
# column name :  url
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  15919
# Value_counts :
#  https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e                  1
# https://www.autoscout24.com//offers/opel-insignia-bus-inno-2-0-cdti-aut-navi-bi-xe-led-e6-diesel-black-8710b253-dd98-4ed0-9d46-cbad2d79532b                1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-10b7463b-9f56-4348-af35-df3432b2b585    1
# https://www.autoscout24.com//offers/opel-insignia-2-0cdti-st-business-innovation-navi-bt-diesel-black-ba5a3368-dedc-4e51-9127-3976b26e93c2                 1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-7b52f054-78d3-4d5e-9370-8a7d081d7edd    1
# ...

# %%
df.shape
# Out:
# (15919, 46)

# %%
# for i in df.url:
#     print(i)

# %%
#diğer kolonlardan sonra drop kararı verilecek

# %% [markdown]
# ### make_model,make ,model column

# %%
df.make_model
# Out:
# 0               Audi A1
# 1               Audi A1
# 2               Audi A1
# 3               Audi A1
# 4               Audi A1
#               ...
# 15914    Renault Espace
# 15915    Renault Espace
# 15916    Renault Espace
# 15917    Renault Espace
# 15918    Renault Espace
# Name: make_model, Length: 15919, dtype: object

# %%
first_look("make_model")
# Out:
# column name :  make_model
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  9
# Value_counts :
#  Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64
#
# Value_counts with sort index :
#  Audi A1           2614
# Audi A2              1
# Audi A3           3097
# Opel Astra        2526
# Opel Corsa        2219
# Opel Insignia     2598
# Renault Clio      1839
# Renault Duster      34
# Renault Espace     991
# Name: make_model, dtype: int64
# ########################################

# %%
df[["make_model","make","model"]].sample(30)
# Out:
#            make_model     make     model
# 15227  Renault Espace  Renault    Espace
# 3297          Audi A3     Audi        A3
# 1705          Audi A1     Audi        A1
# 10998   Opel Insignia     Opel  Insignia
# 5541          Audi A3     Audi        A3
# 12699   Opel Insignia     Opel  Insignia
# 11050   Opel Insignia     Opel  Insignia
# 14160    Renault Clio  Renault      Clio
# 5914       Opel Astra     Opel     Astra
# 13453    Renault Clio  Renault      Clio
# 8183       Opel Astra     Opel     Astra
# 13246    Renault Clio  Renault      Clio
# 4121          Audi A3     Audi        A3
# 15389  Renault Espace  Renault    Espace
# 12662   Opel Insignia     Opel  Insignia
# 11374   Opel Insignia     Opel  Insignia
# 9594       Opel Corsa     Opel     Corsa
# 7582       Opel Astra     Opel     Astra
# 15586  Renault Espace  Renault    Espace
# 8539       Opel Corsa     Opel     Corsa
# 15391  Renault Espace  Renault    Espace
# 10852   Opel Insignia     Opel  Insignia
# ...

# %%
df[["make_model","make","model"]].isna().sum()
# Out:
# make_model    0
# make          0
# model         0
# dtype: int64

# %%
df[["make_model","make","model"]].value_counts()
# Out:
# make_model      make     model
# Audi A3         Audi     A3          3097
# Audi A1         Audi     A1          2614
# Opel Insignia   Opel     Insignia    2598
# Opel Astra      Opel     Astra       2526
# Opel Corsa      Opel     Corsa       2219
# Renault Clio    Renault  Clio        1839
# Renault Espace  Renault  Espace       991
# Renault Duster  Renault  Duster        34
# Audi A2         Audi     A2             1
# dtype: int64

# %%
#drop make,model columns
df.drop(columns=["make","model"],inplace=True)

# %%
df.shape
# Out:
# (15919, 44)

# %% [markdown]
# ### short_description column

# %%
#diğer kolonlara bakıkdıktan sonra null değerlerin doldurulmasına  karar verilebilir.(düşülebilir)
#diğer kolonların doldurulmasında kullanılabilir

# %%
df.short_description
# Out:
# 0               Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1                                            1.8 TFSI sport
# 2        Sportback 1.6 TDI S tronic Einparkhilfe plus+music
# 3                                   1.4 TDi Design S tronic
# 4        Sportback 1.4 TDI S-Tronic S-Line Ext. admired, Xe
#                                 ...
# 15914                 Blue dCi 200CV EDC Executive 4Control
# 15915                   TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916    Blue dCi 200 EDC Initiale Paris Leder LED Navi Key
# 15917    Blue dCi 200CV EDC Business , NUOVA DA IMMATRICOLA
# 15918           INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
# Name: short_description, Length: 15919, dtype: object

# %%
#first_look("short_description")

# %%
for i in df.short_description:
    print(i)
# Out:
# Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1.8 TFSI sport
# Sportback 1.6 TDI S tronic Einparkhilfe plus+music
# 1.4 TDi Design S tronic
# Sportback 1.4 TDI S-Tronic S-Line Ext. admired, Xe
# 1.6 TDI Sport DSG *SHZ*Xenon*Navi*Bose*PDC*
# Sportback 1.6 TDI S-TRONIC S-LINE*NAVI|XENON*
# Sportback 1.4 TDI admired S tronic
# SPB 1.6 TDI S-tronic Metal plus + Xeno
# SPORTBACK TFSI ULTRA 95 S-TRONIC AMB.
# SPORTBACK1.6 TDI 116 CV S tronic Metal plus
# Sportback Sport »1.4 TFSI|Xenon|Navi|EPH+|SHZ|S tr
# Sportback 1.4 TFSI S-tronic *S line*NAV*XEN*
# 1.4 TFSI 150ch COD Ambition Luxe S tronic 7
# Sportback 1.0 TFSI S-TRonic*Navi*Xenon*APS* Sport
# SPB 1.6 TDI 116 CV S tronic Sport
# SPB 1.6 TDI 116 CV Design S-Line SPB 1.6 TDI 116 C
# 1.4 TDi S tronic*S-Line*Navigatie*Euro 6b*
# 1.0 TFSI 95pk Automaat Adrenalin
# Sportback 1.6 TDI 116 CV S tronic Metal plus
# SPB 1.6 TDI 116 CV S tronic Admired S-Line
# Sportback Sport 1.4 TFSI S tronic XENON NAVI
# 1.4 TFSI S tronic
# ...

# %%
get_diff_category_column(df["short_description"]) #kolonlorı incelemek için
# Out:
# {0: '',
#  1: '(2) 1.4 TDI ULTRA 90 AMBIENTE S tronic',
#  2: '(2) 1.6 CDTI 136 ELITE AUTO',
#  3: '(3E GENERATION) III (2) 1.6 TDI 110 BUSINESS LINE',
#  4: '(4) Air Energy dCi 75',
#  5: '(70 PS)/Radio/Klima/BT/CD',
#  6: '(90 PS)/Klima/PDC/Radio/SHZ',
#  7: '(K',
#  8: '(Klim',
#  9: '(RESERVADO)1.3CDTI 95CV/S&S/LL 15"/LED/BLUETOOTH',
#  10: '(€15900',
#  11: '(€5250',
#  12: '(€5600',
#  13: '(€8600',
#  14: '(€8900',
#  15: '(€8950',
#  16: '(€9250',
#  17: ')',
#  18: '0 66kW Klima',
#  19: '0 AT INNOVATION AFL',
#  20: '0 Autom. MATRIX OPC',
#  21: '0 Blue dCi 200 PS EDC',
#  22: '0 CDTI 125 KW EU6 AT Innovation SHZ Alu',
#  23: '0 CDTI Aut 4x4 Innovat Xen Navi Leder',
#  24: '0 CDTI Aut Navi Bi-Xe Led E6',
#  25: '0 CDTI BlueInj Ultimate',
#  26: '0 CDTI BlueInjection Dynamic St./St. Aut',
#  27: '0 CDTI BlueInjection Innovation S./S. Sy. Au',
#  28: '0 CDTI BlueInjection Innovation St',
#  29: '0 CDTI BlueInjection Innovation St./St. Aut',
# ...

# %%
df.groupby(["make_model"])["short_description"].value_counts(dropna=False).head(20)
# Out:
# make_model  short_description
# Audi A1     SPB 30 TFSI S tronic Admired                         34
#             1.4 TDI Design DKG*Navi*PDC*Alu*SHZ*                 27
#             1.4 TFSI Design*PDC*Sport-S*LM-Felgen*SHZ*           27
#             1.6 TDI Sport DSG *SHZ*Xenon*Navi*Bose*PDC*          27
#             1.0 TFSI ultra Sportback                             19
#             Sportback 1.0 TFSI Adrenalin 70 kW (95 C             19
#             1.0 TFSI                                             18
#             30 TFSI                                              18
#             25 TFSI                                              14
#             Sportback 1.4 TDI design Navi+/Xenon/PDC+/SitzHzg    14
#             30 TFSI advanced exterieur                           13
#             SPB 1.6 TDI 116 CV Metal plus                        12
#             Sportback 25 TFSI Advanced 70 kW (95 CV)             11
# ...

# %% [markdown]
# ### body_type column

# %%
df.body_type
# Out:
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
#           ...
# 15914       Van
# 15915       Van
# 15916       Van
# 15917       Van
# 15918       Van
# Name: body_type, Length: 15919, dtype: object

# %%
first_look("body_type")
# Out:
# column name :  body_type
# --------------------------------
# Per_of_Nulls   :  % 0.38
# Num_of_Nulls   :  60
# Num_of_Uniques :  9
# Value_counts :
#  Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64
#
# Value_counts with sort index :
#  Compact          3153
# Convertible         8
# Coupe              25
# Off-Road           56
# Other             290
# Sedans           7903
# Station wagon    3553
# Transporter        88
# Van               783
# NaN                60
# Name: body_type, dtype: int64
# ########################################

# %%
df[["body_type","body"]].isna().sum()
# Out:
# body_type    60
# body         60
# dtype: int64

# %%
df[["body_type","body"]].value_counts(dropna=False)
# Out:
# body_type      body
# Sedans         Sedans           7903
# Station wagon  Station wagon    3553
# Compact        Compact          3153
# Van            Van               783
# Other          Other             290
# Transporter    Transporter        88
# NaN            NaN                60
# Off-Road       Off-Road           56
# Coupe          Coupe              25
# Convertible    Convertible         8
# dtype: int64

# %%
df.groupby(["make_model"])["body_type"].value_counts(dropna=False)
# Out:
# make_model      body_type
# Audi A1         Sedans           1538
#                 Compact          1039
#                 Station wagon      21
#                 Other              13
#                 Coupe               2
#                 Van                 1
# Audi A2         Off-Road            1
# Audi A3         Sedans           2598
#                 Station wagon     282
#                 Compact           182
#                 Other              16
#                 Convertible         8
#                 NaN                 7
#                 Coupe               4
# Opel Astra      Station wagon    1211
#                 Sedans           1053
#                 Compact           185
#                 Other              67
#                 NaN                 7
#                 Coupe               2
#                 Off-Road            1
# Opel Corsa      Compact          1230
#                 Sedans            875
#                 Other              87
# ...

# %%
df[df.body_type.isnull()].isnull().sum()
# Out:
# url                       0
# make_model                0
# short_description         1
# body_type                60
# price                     0
# vat                      40
# km                        0
# registration              0
# prev_owner               51
# hp                        0
# type                      0
# previous_owners          51
# next_inspection          57
# inspection_new           59
# warranty                 55
# full_service             58
# non_smoking_vehicle      58
# offer_number             39
# first_registration       12
# body_color                0
# paint_type               50
# body_color_original      27
# upholstery               52
# body                     60
# nr_of_doors               1
# nr_of_seats              47
# model_code               60
# gearing_type              0
# displacement             23
# cylinders                34
# weight                   52
# drive_chain              58
# fuel                      0
# ...

# %%
#df[df.body_type.isnull()].head()

# %%
#drop body column(body_type ile aynı)
df.drop(columns="body",inplace=True)

# %%
#null değerlere sonra karar verilecek

# %% [markdown]
# ### price column

# %%
first_look("price")
# Out:
# column name :  price
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  2956
# Value_counts :
#  14990    154
# 15990    151
# 10990    139
# 15900    106
# 17990    102
#         ...
# 17559      1
# 17560      1
# 17570      1
# 17575      1
# 39875      1
# Name: price, Length: 2956, dtype: int64
#
# Value_counts with sort index :
#  13       1
# 120      1
# 255      1
# 331      1
# 4950     1
#         ..
# 64332    1
# 64900    1
# 67600    1
# 68320    1
# 74600    1
# Name: price, Length: 2956, dtype: int64
# ########################################

# %% [markdown]
# ### vat column

# %%
df.vat
# Out:
# 0          VAT deductible
# 1        Price negotiable
# 2          VAT deductible
# 3                    None
# 4                    None
#                ...
# 15914      VAT deductible
# 15915      VAT deductible
# 15916      VAT deductible
# 15917      VAT deductible
# 15918      VAT deductible
# Name: vat, Length: 15919, dtype: object

# %%
first_look("vat")
# Out:
# column name :  vat
# --------------------------------
# Per_of_Nulls   :  % 28.35
# Num_of_Nulls   :  4513
# Num_of_Uniques :  2
# Value_counts :
#  VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64
#
# Value_counts with sort index :
#  Price negotiable      426
# VAT deductible      10980
# NaN                  4513
# Name: vat, dtype: int64
# ########################################

# %%
#null değerlere ne yyapılacağına sonra karar verilecek.

# %% [markdown]
# ### km column

# %%
df.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914         - km
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918         - km
# Name: km, Length: 15919, dtype: object

# %%
first_look("km")
# Out:
# column name :  km
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  6690
# Value_counts :
#  10 km        1045
# - km         1024
# 1 km          367
# 5 km          170
# 50 km         148
#              ...
# 67,469 km       1
# 43,197 km       1
# 10,027 km       1
# 35,882 km       1
# 57 km           1
# Name: km, Length: 6690, dtype: int64
#
# Value_counts with sort index :
#  - km         1024
# 0 km           19
# 1 km          367
# 1,000 km       46
# 1,001 km        4
#              ...
# 99,999 km       1
# 990 km          2
# 991 km          1
# 995 km          1
# 999 km          3
# Name: km, Length: 6690, dtype: int64
# ########################################

# %%
df["km"]=df.km.str.strip(" km").str.replace(",","").replace("-",np.nan,regex=True).astype(float)

# %%
first_look("km")
# Out:
# column name :  km
# --------------------------------
# Per_of_Nulls   :  % 6.43
# Num_of_Nulls   :  1024
# Num_of_Uniques :  6689
# Value_counts :
#  10.0       1045
# NaN        1024
# 1.0         367
# 5.0         170
# 50.0        148
#            ...
# 67469.0       1
# 43197.0       1
# 10027.0       1
# 35882.0       1
# 57.0          1
# Name: km, Length: 6690, dtype: int64
#
# Value_counts with sort index :
#  0.0           19
# 1.0          367
# 2.0            6
# 3.0           33
# 4.0           15
#             ...
# 248000.0       1
# 260000.0       1
# 291800.0       1
# 317000.0       1
# NaN         1024
# Name: km, Length: 6690, dtype: int64
# ########################################

# %% [markdown]
# ### registration and first_registration columns

# %%
df.registration
# Out:
# 0        01/2016
# 1        03/2017
# 2        02/2016
# 3        08/2016
# 4        05/2016
#           ...
# 15914        -/-
# 15915    01/2019
# 15916    03/2019
# 15917    06/2019
# 15918    01/2019
# Name: registration, Length: 15919, dtype: object

# %%
first_look("registration")
# Out:
# column name :  registration
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  48
# Value_counts :
#  -/-        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 01/2019     541
# 04/2018     541
# 02/2018     539
# 03/2016     536
# 04/2016     532
# 06/2018     532
# 01/2018     511
# 04/2019     506
# 02/2016     472
# 03/2017     471
# 05/2016     459
# 06/2016     452
# 05/2019     440
# 06/2017     409
# 05/2017     404
# 07/2018     396
# 04/2017     380
# 01/2016     376
# 02/2017     368
# 01/2017     306
# 08/2018     285
# 06/2019     224
# 07/2017     215
# 11/2017     180
# 07/2016     176
# 10/2016     160
# 10/2017     154
# 09/2017     149
# 11/2016     142
# 09/2018     141
# 09/2016     141
# 12/2016     134
# 12/2017     123
# 08/2017     114
# 11/2018     110
# 12/2018     103
# 10/2018      97
# 08/2016      94
# 07/2019       6
# 09/2019       5
# 08/2019       1
# 11/2019       1
# ...

# %%
df[["registration","first_registration"]].value_counts(dropna=False).head()
# Out:
# registration  first_registration
# -/-           NaN                   1597
# 03/2018       2018                   695
# 02/2019       2019                   585
# 05/2018       2018                   572
# 03/2019       2019                   543
# dtype: int64

# %%
#df.groupby(["make_model","first_registration","registration"])["price"].apply(list)

# %%
df.groupby(["make_model","registration"])["price"].describe().head()
# Out:
#                          count          mean          std      min      25%  \
# make_model registration
# Audi A1    -/-           326.0  23203.711656  3671.500600  14900.0  20388.0
#            01/2016        45.0  14561.288889  1889.311546  10800.0  13420.0
#            01/2017        28.0  15748.750000  2148.529051  11990.0  14500.0
#            01/2018        51.0  18292.784314  2567.225875  14960.0  16390.0
#            01/2019        93.0  24087.365591  3055.006414  15990.0  21990.0
#
#                              50%      75%      max
# make_model registration
# Audi A1    -/-           22400.0  26987.5  31990.0
#            01/2016       14380.0  15970.0  18880.0
#            01/2017       15590.0  16197.5  20800.0
#            01/2018       16950.0  19990.0  23550.0
#            01/2019       23480.0  26494.0  29000.0

# %%
#drop registration
df.drop(columns="registration",inplace=True)

# %%
df.shape
# Out:
# (15919, 42)

# %%
#replace "-/-" values with np.nan in firs_registration column
df.first_registration.replace("-/-",np.nan,inplace=True)

# %%
#fixing data type
df["first_registration"] = df.first_registration.astype(float)

# %%
df["first_registration"].isnull().sum()
# Out:
# 1597

# %%
#null değerlere sonra bakılacak

# %% [markdown]
# ### prev_owner and previous_owners columns

# %%
first_look("prev_owner")
# Out:
# column name :  prev_owner
# --------------------------------
# Per_of_Nulls   :  % 42.89
# Num_of_Nulls   :  6828
# Num_of_Uniques :  4
# Value_counts :
#  1 previous owner     8294
# NaN                  6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64
#
# Value_counts with sort index :
#  1 previous owner     8294
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# NaN                  6828
# Name: prev_owner, dtype: int64
# ########################################

# %%
df[["prev_owner","previous_owners"]]
# Out:
#               prev_owner  \
# 0      2 previous owners
# 1                   None
# 2       1 previous owner
# 3       1 previous owner
# 4       1 previous owner
# ...                  ...
# 15914               None
# 15915   1 previous owner
# 15916   1 previous owner
# 15917               None
# 15918   1 previous owner
#
#                                                      previous_owners
# 0                                                                  2
# 1                                                                NaN
# 2                                                                  1
# 3                                                                  1
# 4                                                                  1
# ...                                                              ...
# 15914                                                            NaN
# 15915  17.4 l/100 km (comb)9.2 l/100 km (city)6.3 l/100 km (country)
# ...

# %%
df[["prev_owner","previous_owners","consumption"]]
# Out:
#               prev_owner  \
# 0      2 previous owners
# 1                   None
# 2       1 previous owner
# 3       1 previous owner
# 4       1 previous owner
# ...                  ...
# 15914               None
# 15915   1 previous owner
# 15916   1 previous owner
# 15917               None
# 15918   1 previous owner
#
#                                                      previous_owners  \
# 0                                                                  2
# 1                                                                NaN
# 2                                                                  1
# 3                                                                  1
# 4                                                                  1
# ...                                                              ...
# 15914                                                            NaN
# 15915  17.4 l/100 km (comb)9.2 l/100 km (city)6.3 l/100 km (country)
# ...

# %%
df.prev_owner.str.extract("(\d+)").value_counts(dropna=False)
# Out:
# 1      8294
# NaN    6828
# 2       778
# 3        17
# 4         2
# dtype: int64

# %%
#extracting number of owner from prev_owner
df["prev_owner"]=df.prev_owner.str.extract("(\d)").astype(float)

# %%
df[["prev_owner","previous_owners"]].isnull().sum()
# Out:
# prev_owner         6828
# previous_owners    6640
# dtype: int64

# %%
#prev ovner sutunu temizlendi null değerler diğer ilişkili kolonlarla değer.

# %% [markdown]
# ### hp column

# %%
df.hp
# Out:
# 0         66 kW
# 1        141 kW
# 2         85 kW
# 3         66 kW
# 4         66 kW
#           ...
# 15914    147 kW
# 15915    165 kW
# 15916    146 kW
# 15917    147 kW
# 15918    165 kW
# Name: hp, Length: 15919, dtype: object

# %%
first_look("hp")
# Out:
# column name :  hp
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  81
# Value_counts :
#  85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
# 70 kW      888
# 125 kW     707
# 51 kW      695
# 55 kW      569
# 118 kW     516
# 92 kW      466
# 121 kW     392
# 147 kW     380
# 77 kW      345
# 56 kW      286
# 54 kW      276
# 103 kW     253
# 87 kW      232
# 165 kW     194
# 88 kW      177
# 60 kW      160
# 162 kW      98
# - kW        88
# 74 kW       81
# 96 kW       72
# 71 kW       59
# 101 kW      47
# 67 kW       40
# 154 kW      39
# 122 kW      35
# 119 kW      30
# 164 kW      27
# 135 kW      24
# 82 kW       22
# 52 kW       22
# 78 kW       20
# 1 kW        20
# 294 kW      18
# 146 kW      18
# 141 kW      16
# 57 kW       10
# 104 kW       8
# 120 kW       8
# 191 kW       7
# 112 kW       7
# 155 kW       6
# 117 kW       6
# 184 kW       5
# 90 kW        4
# 76 kW        4
# ...

# %%
df["hp_kw"]=df.hp.str.extract(r"(\d+)").astype(float)

# %%
#drop hp column
df.drop(columns="hp",inplace=True)

# %%
df.shape  #(42 kolon olmalı)
# Out:
# (15919, 42)

# %%
df.hp_kw.isnull().sum()
# Out:
# 88

# %%
df.groupby(["make_model"])["hp_kw"].value_counts().head(30)
# Out:
# make_model  hp_kw
# Audi A1     85.0      890
#             70.0      791
#             66.0      465
#             92.0      172
#             60.0      156
#             71.0       56
#             110.0      30
#             141.0      16
#             147.0      14
#             67.0       12
#             87.0        4
#             93.0        3
#             86.0        1
#             112.0       1
#             140.0       1
# Audi A2     85.0        1
# Audi A3     85.0     1629
#             81.0      785
#             110.0     503
#             92.0       93
#             135.0      24
#             294.0      18
#             82.0       15
#             96.0        9
#             87.0        6
#             228.0       2
#             270.0       2
#             9.0         1
#             86.0        1
#             100.0       1
# Name: hp_kw, dtype: int64

# %%
# NOT: null lara sonra bakılacak.

# %% [markdown]
# ### type column

# %%
df.type
# Out:
# 0                          ,Used,,Diesel (Particulate Filter)
# 1                                             ,Used,,Gasoline
# 2                          ,Used,,Diesel (Particulate Filter)
# 3                          ,Used,,Diesel (Particulate Filter)
# 4                          ,Used,,Diesel (Particulate Filter)
#                                  ...
# 15914                       ,New,,Diesel (Particulate Filter)
# 15915    ,Used,,Super 95 / Super Plus 98 (Particulate Filter)
# 15916                                 ,Pre-registered,,Diesel
# 15917                                 ,Pre-registered,,Diesel
# 15918                                ,Demonstration,,Super 95
# Name: type, Length: 15919, dtype: object

# %%
first_look("type")
# Out:
# column name :  type
# --------------------------------
# Per_of_Nulls   :  % 0.01
# Num_of_Nulls   :  2
# Num_of_Uniques :  169
# Value_counts :
#  ,Used,,Diesel (Particulate Filter)                                                                                 3475
# ,Used,,Diesel                                                                                                      2516
# ,Used,,Gasoline                                                                                                    2367
# ,Used,,Super 95                                                                                                    1818
# ,Pre-registered,,Super 95                                                                                           500
#                                                                                                                    ...
# ...

# %%
df[["type","fuel"]].sample(5)
# Out:
#                                        type                           fuel
# 538               ,Used,,Regular/Benzine 91             Regular/Benzine 91
# 12404                ,Demonstration,,Diesel                         Diesel
# 8997   ,Used,,Super 95 / Regular/Benzine 91  Super 95 / Regular/Benzine 91
# 8353              ,Employee's car,,Super 95                       Super 95
# 11726                   ,Used,,Super E10 95                   Super E10 95

# %%
df.type.str.split(",").str[1].value_counts()  # veya apply lambda (split)ile ya da extract ile de yapılabilir
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# Name: type, dtype: int64

# %%
df.type.str.split(",").str[1].isnull().sum()
# Out:
# 2

# %%
df["type"] = df.type.str.split(",").str[1]
df.type
# Out:
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
#               ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
# Name: type, Length: 15919, dtype: object

# %%
# NOT: null değerlere sonra bakılacak.

# %% [markdown]
# ### next_inspection column

# %%
df.next_inspection
# Out:
# 0         06/202199 g CO2/km (comb)
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#                     ...
# 15914                           NaN
# 15915    01/2022168 g CO2/km (comb)
# 15916                           NaN
# 15917                           NaN
# 15918                           NaN
# Name: next_inspection, Length: 15919, dtype: object

# %%
first_look("next_inspection")
# Out:
# column name :  next_inspection
# --------------------------------
# Per_of_Nulls   :  % 77.79
# Num_of_Nulls   :  12384
# Num_of_Uniques :  1384
# Value_counts :
#  NaN                           12384
# 04/2022                          62
# 06/2021                          47
# 03/2021                          39
# 03/2022                          36
#                               ...
# 06/2021121 g CO2/km (comb)        1
# 02/2020139 g CO2/km (comb)        1
# 10/2021136 g CO2/km (comb)        1
# 06/2019139 g CO2/km (comb)        1
# 01/2022168 g CO2/km (comb)        1
# Name: next_inspection, Length: 1385, dtype: int64
#
# Value_counts with sort index :
#  01/1921120 g CO2/km (comb)                                               1
# 01/1955                                                                  1
# 01/1999                                                                  1
# 01/2001120 g CO2/km (comb)                                               1
# ...

# %%
df[["next_inspection","inspection_new"]].head(10)
# Out:
#              next_inspection          inspection_new
# 0  06/202199 g CO2/km (comb)               YesEuro 6
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN  Yes109 g CO2/km (comb)
# 5                        NaN                     NaN
# 6                        NaN   Yes98 g CO2/km (comb)
# 7                        NaN   Yes97 g CO2/km (comb)
# 8  02/202097 g CO2/km (comb)                     NaN
# 9                        NaN                     NaN

# %%
#sadece tarih değerlerini elde ettik "null" değerleri yüksek olduğu için düşülebilir
df["next_insp_date"] = df.next_inspection.str.extract(r"(\d+/\d{0,4})")#

# %%
df["next_insp_date"].isnull().sum()
# Out:
# 12384

# %%
# NOT: null değerlere sonra bakılacak.

# %% [markdown]
# ### inspection_new column

# %%
df.inspection_new
# Out:
# 0                     YesEuro 6
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4        Yes109 g CO2/km (comb)
#                   ...
# 15914                       NaN
# 15915                       NaN
# 15916           YesEuro 6d-TEMP
# 15917                       NaN
# 15918    Yes153 g CO2/km (comb)
# Name: inspection_new, Length: 15919, dtype: object

# %%
first_look("inspection_new")
# Out:
# column name :  inspection_new
# --------------------------------
# Per_of_Nulls   :  % 75.3
# Num_of_Nulls   :  11987
# Num_of_Uniques :  201
# Value_counts :
#  NaN                                                                11987
# YesEuro 6                                                            523
# Yes                                                                  442
# Yes102 g CO2/km (comb)                                               174
# Yes4 (Green)                                                         166
#                                                                    ...
# Yes5.2 l/100 km (comb)6.7 l/100 km (city)4.2 l/100 km (country)        1
# Yes100 g CO2/km (comb)                                                 1
# Yes4.9 l/100 km (comb)5.9 l/100 km (city)4.3 l/100 km (country)        1
# Yes5.1 l/100 km (comb)6.4 l/100 km (city)4.3 l/100 km (country)        1
# Yes172 g CO2/km (comb)                                                 1
# ...

# %%
#df.inspection_new.str.extract(r"(No)")

# %%
df.inspection_new.str.extract(r"(Yes)")
# Out:
#          0
# 0      Yes
# 1      NaN
# 2      NaN
# 3      NaN
# 4      Yes
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  Yes
# 15917  NaN
# 15918  Yes
#
# [15919 rows x 1 columns]

# %%
df["insp_new"] = df.inspection_new.str.extract(r"(Yes)")

# %%
df["insp_new"].value_counts(dropna=False).head()
# Out:
# NaN    11987
# Yes     3932
# Name: insp_new, dtype: int64

# %%
# NOT: nullara sonra bakılacak.

# %% [markdown]
# ### warranty column

# %%
df.warranty.head(10)
# Out:
# 0             4 (Green)
# 1                   NaN
# 2    99 g CO2/km (comb)
# 3                   NaN
# 4                Euro 6
# 5                   NaN
# 6                   NaN
# 7                Euro 6
# 8       12 monthsEuro 6
# 9              3 months
# Name: warranty, dtype: object

# %%
first_look("warranty")
# Out:
# column name :  warranty
# --------------------------------
# Per_of_Nulls   :  % 42.48
# Num_of_Nulls   :  6763
# Num_of_Uniques :  505
# Value_counts :
#  NaN                                                                    6763
# Euro 6                                                                 1868
# 12 months                                                              1305
# 24 months                                                               585
# 4 (Green)                                                               517
#                                                                        ...
# 2 months                                                                  1
# 72 months125 g CO2/km (comb)                                              1
# 60 months14 g CO2/km (comb)                                               1
# 24 months121 g CO2/km (comb)                                              1
# ...

# %%
df.warranty.str.extract(r"(\d+)\s* month").notna().sum()#(r"(\d+) month")
# Out:
# 0    4853
# dtype: int64

# %%
df["warranty_month"] = df.warranty.str.extract(r"(\d+)\s*month").astype(float)

# %%
df["warranty_month"].isnull().sum()
# Out:
# 11066

# %%
df.shape
# Out:
# (15919, 45)

# %%
# NOT: Nulllara sonra bakılacak.

# %% [markdown]
# ### full_service column

# %%
df.full_service#.isnull().sum()
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3        99 g CO2/km (comb)
# 4                 4 (Green)
#                 ...
# 15914                   NaN
# 15915                   NaN
# 15916                   NaN
# 15917                   NaN
# 15918                   NaN
# Name: full_service, Length: 15919, dtype: object

# %%
first_look("full_service")
# Out:
# column name :  full_service
# --------------------------------
# Per_of_Nulls   :  % 60.86
# Num_of_Nulls   :  9689
# Num_of_Uniques :  120
# Value_counts :
#  NaN                                                             9689
# 4 (Green)                                                       2235
# Euro 6                                                          2097
# Euro 6d-TEMP                                                     399
# 120 g CO2/km (comb)                                              105
#                                                                 ...
# 6 l/100 km (comb)8 l/100 km (city)4.9 l/100 km (country)           1
# 84 g CO2/km (comb)                                                 1
# 87 g CO2/km (comb)                                                 1
# 5.7 l/100 km (comb)7.3 l/100 km (city)4.9 l/100 km (country)       1
# Euro 4                                                             1
# Name: full_service, Length: 121, dtype: int64
#
# ...

# %%
df.full_service.isnull().sum()
# Out:
# 9689

# %%
#full servis column can be used to fiil ,şu an için bıraktık
#içerisinde emiission,co_2_emission bilgileri var

# %% [markdown]
# ### non_smoking_vehicle column

# %%
df.non_smoking_vehicle
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3           Euro 6
# 4              NaN
#            ...
# 15914          NaN
# 15915    4 (Green)
# 15916          NaN
# 15917          NaN
# 15918          NaN
# Name: non_smoking_vehicle, Length: 15919, dtype: object

# %%
first_look("non_smoking_vehicle")
# Out:
# column name :  non_smoking_vehicle
# --------------------------------
# Per_of_Nulls   :  % 78.26
# Num_of_Nulls   :  12459
# Num_of_Uniques :  92
# Value_counts :
#  NaN                                                             12459
# 4 (Green)                                                        1240
# Euro 6                                                           1127
# Euro 6d-TEMP                                                      345
# 120 g CO2/km (comb)                                                63
# 85 g CO2/km (comb)                                                 46
# 107 g CO2/km (comb)                                                36
# 104 g CO2/km (comb)                                                36
# 153 g CO2/km (comb)                                                31
# 124 g CO2/km (comb)                                                29
# 1 (No sticker)                                                     24
# ...

# %%
#diğer kolonların doldurulmasında kullanılabilir sonrasında düşülecek

# %% [markdown]
# ### offer_number column

# %%
df.offer_number
# Out:
# 0             LR-062483
# 1                   NaN
# 2              AM-95365
# 3                   NaN
# 4                 C1626
#               ...
# 15914          10988301
# 15915       507370_3223
# 15916          Espace16
# 15917           2691331
# 15918    Re_30000008029
# Name: offer_number, Length: 15919, dtype: object

# %%
first_look("offer_number")
# Out:
# column name :  offer_number
# --------------------------------
# Per_of_Nulls   :  % 19.94
# Num_of_Nulls   :  3175
# Num_of_Uniques :  11440
# Value_counts :
#  NaN                                         3175
# LT67679                                       27
# UN89904                                       27
# XJ38068                                       27
# JV03654                                       27
#                                             ...
# 160_dcbb6c3e-a6da-43a3-8754-ccd994cec93b       1
# 6701576                                        1
# 6701569                                        1
# 158121                                         1
# Re_30000008029                                 1
# Name: offer_number, Length: 11441, dtype: int64
#
# Value_counts with sort index :
#  # 250678          1
# # 8H6050830       1
# # G1024529        1
# # G6050580        1
# #8023778          2
#                ...
# x_45689v          2
# y8fx64x           1
# ...

# %%
#drop edilecek
df.drop(columns="offer_number",inplace=True)

# %%
df.shape
# Out:
# (15919, 44)

# %% [markdown]
# ### body_color column

# %%
first_look("body_color")
# Out:
# column name :  body_color
# --------------------------------
# Per_of_Nulls   :  % 3.75
# Num_of_Nulls   :  597
# Num_of_Uniques :  14
# Value_counts :
#  Black     3745
# Grey      3505
# White     3406
# Silver    1647
# Blue      1431
# Red        957
# NaN        597
# Brown      289
# Green      154
# Beige      108
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64
#
# Value_counts with sort index :
#  Beige      108
# Black     3745
# Blue      1431
# Bronze       6
# Brown      289
# Gold         2
# Green      154
# Grey      3505
# Orange       3
# Red        957
# Silver    1647
# Violet      18
# White     3406
# Yellow      51
# NaN        597
# Name: body_color, dtype: int64
# ########################################

# %%
#Null değerere bakılacak

# %% [markdown]
# ### paint_type column

# %%
df.paint_type
# Out:
# 0        Metallic
# 1             NaN
# 2        Metallic
# 3        Metallic
# 4        Metallic
#            ...
# 15914    Metallic
# 15915    Metallic
# 15916         NaN
# 15917         NaN
# 15918    Metallic
# Name: paint_type, Length: 15919, dtype: object

# %%
first_look("paint_type")
# Out:
# column name :  paint_type
# --------------------------------
# Per_of_Nulls   :  % 36.26
# Num_of_Nulls   :  5772
# Num_of_Uniques :  3
# Value_counts :
#  Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: paint_type, dtype: int64
#
# Value_counts with sort index :
#  Metallic       9794
# Perl effect       6
# Uni/basic       347
# NaN            5772
# Name: paint_type, dtype: int64
# ########################################

# %%
#Nullara ne yapacağımıza karar verecğiz

# %% [markdown]
# ### body_color_original column

# %%
df.body_color_original
# Out:
# 0                 Mythosschwarz
# 1                           NaN
# 2        mythosschwarz metallic
# 3                           NaN
# 4        Mythosschwarz Metallic
#                   ...
# 15914              Grigio scuro
# 15915       Stahl-Grau Metallic
# 15916               arktis-weiß
# 15917                    Grigio
# 15918    Titanium-Grau Metallic
# Name: body_color_original, Length: 15919, dtype: object

# %%
first_look("body_color_original")
# Out:
# column name :  body_color_original
# --------------------------------
# Per_of_Nulls   :  % 23.61
# Num_of_Nulls   :  3759
# Num_of_Uniques :  1927
# Value_counts :
#  NaN                              3759
# Onyx Schwarz                      338
# Bianco                            282
# Mythosschwarz Metallic            238
# Brillantschwarz                   216
#                                  ...
# Rouge-Braun (G0Y)                   1
# VARI COLRI DISPONIBILI              1
# Kokosnussbraun Metallic             1
# Farbe frei wählbar                  1
# Perlmutt-Weiß Metallic (Weiß)       1
# Name: body_color_original, Length: 1928, dtype: int64
#
# Value_counts with sort index :
#  "PLATIN"                          1
# "satinsilber "                    1
# (0C0C) Monsungrau Metallic        1
# (B4B4) Cortinaweiss               1
# (NNP)                             1
#                                ...
# wählbar - ggf. mit Aufpreis     118
# ...

# %%
df[["body_color","paint_type","body_color_original"]].sample(30)
# Out:
#       body_color paint_type       body_color_original
# 6125        Grey   Metallic                      gris
# 839        Brown   Metallic                       NaN
# 9808         Red        NaN                  Lava Rot
# 10160       Grey   Metallic                       NaN
# 3819        Grey   Metallic                      gris
# 10841     Silver   Metallic              argon silber
# 14893      White        NaN         Arktis-Weiß (369)
# 2606       Black   Metallic                      Mito
# 13813       Grey   Metallic                       NaN
# 3469        Grey   Metallic                       NaN
# 7923      Silver   Metallic                       NaN
# 4249       Black        NaN           brillantschwarz
# 8876        Blue   Metallic                      bleu
# 5510      Silver   Metallic            Argento floret
# 4227         NaN        NaN                   wählbar
# 13628      White        NaN                    Bianco
# ...

# %%
# column drop body_color_original
df.drop(columns="body_color_original",inplace=True)

# %%
df.shape
# Out:
# (15919, 43)

# %% [markdown]
# ### upholstery column

# %%
first_look("upholstery")
# Out:
# column name :  upholstery
# --------------------------------
# Per_of_Nulls   :  % 23.37
# Num_of_Nulls   :  3720
# Num_of_Uniques :  46
# Value_counts :
#  Cloth, Black           5821
# NaN                    3720
# Part leather, Black    1121
# Cloth                  1005
# Cloth, Grey             891
# Cloth, Other            639
# Full leather, Black     575
# Black                   491
# Grey                    273
# Other, Other            182
# Part leather            140
# Full leather            139
# Full leather, Brown     116
# Part leather, Grey      116
# Other, Black            110
# Full leather, Other      72
# Full leather, Grey       67
# Part leather, Other      65
# Other                    56
# Part leather, Brown      50
# alcantara, Black         47
# Velour, Black            36
# Full leather, Beige      36
# Cloth, Brown             28
# Velour                   16
# Other, Grey              15
# Cloth, Beige             13
# Brown                    12
# ...

# %%
df.upholstery.str.extract(r"(.+),(.+)").value_counts(dropna=False)#burada tek başına kumaş ve rengi alamıyoruz
# Out:
# 0             1
# NaN           NaN        5861
# Cloth          Black     5821
# Part leather   Black     1121
# Cloth          Grey       891
#                Other      639
# Full leather   Black      575
# Other          Other      182
# Part leather   Grey       116
# Full leather   Brown      116
# Other          Black      110
# Full leather   Other       72
#                Grey        67
# Part leather   Other       65
#                Brown       50
# alcantara      Black       47
# Full leather   Beige       36
# Velour         Black       36
# Cloth          Brown       28
# Other          Grey        15
# Cloth          Beige       13
#                Blue        12
# Velour         Grey         8
# Cloth          White        8
# alcantara      Grey         6
# Cloth          Red          5
# Other          Yellow       4
# Part leather   Red          3
# Full leather   Blue         2
# Part leather   White        2
# alcantara      Other        2
# ...

# %%
df.upholstery.str.split(", ").str[0].value_counts(dropna=False)
# Out:
# Cloth           8423
# NaN             3720
# Part leather    1499
# Full leather    1009
# Black            491
# Other            368
# Grey             273
# Velour            60
# alcantara         57
# Brown             12
# Beige              3
# Blue               2
# White              2
# Name: upholstery, dtype: int64

# %%
type = ["Cloth", 'Part leather', 'Full leather', 'Velour', 'alcantara',"Other"]
color = ['Black', 'Grey', 'Brown', 'Beige', 'White', 'Blue', 'Red', 'Yellow', 'Orange']

# %%
a_type=df.upholstery.str.split(", ").str[0]
a_type
# Out:
# 0               Cloth
# 1               Cloth
# 2               Cloth
# 3                 NaN
# 4               Cloth
#              ...
# 15914             NaN
# 15915           Cloth
# 15916    Full leather
# 15917    Part leather
# 15918    Full leather
# Name: upholstery, Length: 15919, dtype: object

# %%
a_type.value_counts()
# Out:
# Cloth           8423
# Part leather    1499
# Full leather    1009
# Black            491
# Other            368
# Grey             273
# Velour            60
# alcantara         57
# Brown             12
# Beige              3
# Blue               2
# White              2
# Name: upholstery, dtype: int64

# %%
a_type[a_type.isin(color)]
# Out:
# 29       Black
# 64       Black
# 112      Black
# 180       Grey
# 194       Blue
#          ...
# 15716    Black
# 15777    Brown
# 15866    Brown
# 15896     Grey
# 15902    Brown
# Name: upholstery, Length: 783, dtype: object

# %%
a_color=a_type[a_type.isin(color)]
a_color
# Out:
# 29       Black
# 64       Black
# 112      Black
# 180       Grey
# 194       Blue
#          ...
# 15716    Black
# 15777    Brown
# 15866    Brown
# 15896     Grey
# 15902    Brown
# Name: upholstery, Length: 783, dtype: object

# %%
b_color=df.upholstery.str.split(", ").str[1]
b_color.value_counts()
# Out:
# Black     7710
# Grey      1103
# Other      960
# Brown      195
# Beige       51
# Blue        14
# White       11
# Red          9
# Yellow       4
# Orange       1
# Name: upholstery, dtype: int64

# %%
b_color.fillna(a_color,inplace=True)

# %%
a_type[a_type.isin(color)] = np.nan

# %%
df["upholstery_type"] = a_type
df["upholstery_color"] = b_color

# %%
df.upholstery_type.notna().sum()
# Out:
# 11416

# %%
df.upholstery_color.notna().sum()
# Out:
# 10841

# %%
#df[["upholstery","upholstery_type","upholstery_color"]].sample(60)

# %%
#drop columns
df.drop(columns="upholstery",inplace=True)

# %%
df.shape
# Out:
# (15919, 44)

# %% [markdown]
# ### nr_of_doors column

# %%
df.nr_of_doors
# Out:
# 0        5
# 1        3
# 2        4
# 3        3
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    5
# 15917    5
# 15918    5
# Name: nr_of_doors, Length: 15919, dtype: object

# %%
first_look("nr_of_doors")
# Out:
# column name :  nr_of_doors
# --------------------------------
# Per_of_Nulls   :  % 1.33
# Num_of_Nulls   :  212
# Num_of_Uniques :  6
# Value_counts :
#  5      11575
# 4       3079
# 3        832
# 2        219
# NaN      212
# 1          1
# 7          1
# Name: nr_of_doors, dtype: int64
#
# Value_counts with sort index :
#  1          1
# 2        219
# 3        832
# 4       3079
# 5      11575
# 7          1
# NaN      212
# Name: nr_of_doors, dtype: int64
# ########################################

# %%
#fixing data type
df["nr_of_doors"]=df.nr_of_doors.astype(float)

# %%
# null verilere bakılacak

# %% [markdown]
# ### nr_of_seats column

# %%
first_look("nr_of_seats")
# Out:
# column name :  nr_of_seats
# --------------------------------
# Per_of_Nulls   :  % 6.14
# Num_of_Nulls   :  977
# Num_of_Uniques :  6
# Value_counts :
#  5      13336
# 4       1125
# NaN      977
# 7        362
# 2        116
# 6          2
# 3          1
# Name: nr_of_seats, dtype: int64
#
# Value_counts with sort index :
#  2        116
# 3          1
# 4       1125
# 5      13336
# 6          2
# 7        362
# NaN      977
# Name: nr_of_seats, dtype: int64
# ########################################

# %%
#fixing data type
df["nr_of_seats"]=df.nr_of_seats.astype(float)

# %% [markdown]
# ### model_code column

# %%
first_look("model_code")
# Out:
# column name :  model_code
# --------------------------------
# Per_of_Nulls   :  % 68.73
# Num_of_Nulls   :  10941
# Num_of_Uniques :  232
# Value_counts :
#  NaN         10941
# 0035/BCB      268
# 0588/BNO      245
# 0588/BDB      206
# 0588/BHX      188
#             ...
# 0035/AVN        1
# 0035/BEM        1
# 0035/BAG        1
# 0035/BAA        1
# 3333/BKG        1
# Name: model_code, Length: 233, dtype: int64
#
# Value_counts with sort index :
#  0000/000       21
# 0000/035        1
# 0000/ACP        1
# 0035/AAA        1
# 0035/AAD        1
#             ...
# 3333/BJR       79
# 3333/BKG        1
# 3333/BKQ       18
# 3333/BKR        8
# NaN         10941
# Name: model_code, Length: 233, dtype: int64
# ########################################

# %%
#drop model_code column
df.drop(columns="model_code",inplace=True)

# %%
df.shape
# Out:
# (15919, 43)

# %% [markdown]
# ### gearing_type column

# %%
df.gearing_type
# Out:
# 0        Automatic
# 1        Automatic
# 2        Automatic
# 3        Automatic
# 4        Automatic
#            ...
# 15914    Automatic
# 15915    Automatic
# 15916    Automatic
# 15917    Automatic
# 15918    Automatic
# Name: gearing_type, Length: 15919, dtype: object

# %%
first_look("gearing_type")
# Out:
# column name :  gearing_type
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  3
# Value_counts :
#  Manual            8153
# Automatic         7297
# Semi-automatic     469
# Name: gearing_type, dtype: int64
#
# Value_counts with sort index :
#  Automatic         7297
# Manual            8153
# Semi-automatic     469
# Name: gearing_type, dtype: int64
# ########################################

# %% [markdown]
# ### displacement column

# %%
first_look("displacement")
# Out:
# column name :  displacement
# --------------------------------
# Per_of_Nulls   :  % 3.12
# Num_of_Nulls   :  496
# Num_of_Uniques :  77
# Value_counts :
#  1,598 cc     4761
# 999 cc       2438
# 1,398 cc     1314
# 1,399 cc      749
# 1,229 cc      677
# 1,956 cc      670
# 1,461 cc      595
# 1,490 cc      559
# NaN           496
# 1,422 cc      467
# 1,197 cc      353
# 898 cc        351
# 1,395 cc      320
# 1,968 cc      301
# 1,149 cc      288
# 1,618 cc      212
# 1,798 cc      210
# 1,498 cc      196
# 1,600 cc      130
# 1,248 cc      110
# 1,997 cc      103
# 1,364 cc      102
# 1,400 cc       90
# 998 cc         72
# 1,500 cc       50
# 2,000 cc       46
# 1,000 cc       40
# 1 cc           36
# 1,998 cc       25
# 2,480 cc       20
# 1,200 cc       18
# 1,984 cc       18
# 1,397 cc       11
# 899 cc         11
# 160 cc          6
# 929 cc          5
# 1,499 cc        5
# 997 cc          4
# 1,596 cc        4
# 139 cc          4
# 900 cc          4
# 1,599 cc        3
# ...

# %%
df["displacement"] = df.displacement.str.replace(",","").str.extract(r"(\d+)").astype(float)

# %%
df.displacement
# Out:
# 0        1422.0
# 1        1798.0
# 2        1598.0
# 3        1422.0
# 4        1422.0
#           ...
# 15914    1997.0
# 15915    1798.0
# 15916    1997.0
# 15917    1997.0
# 15918    1798.0
# Name: displacement, Length: 15919, dtype: float64

# %%
df.rename(columns={"displacement":"displacement_cc"},inplace=True)

# %%
#null verilere bakıacak

# %% [markdown]
# ### cylinders column

# %%
first_look("cylinders")
# Out:
# column name :  cylinders
# --------------------------------
# Per_of_Nulls   :  % 35.68
# Num_of_Nulls   :  5680
# Num_of_Uniques :  7
# Value_counts :
#  4      8105
# NaN    5680
# 3      2104
# 5        22
# 6         3
# 8         2
# 2         2
# 1         1
# Name: cylinders, dtype: int64
#
# Value_counts with sort index :
#  1         1
# 2         2
# 3      2104
# 4      8105
# 5        22
# 6         3
# 8         2
# NaN    5680
# Name: cylinders, dtype: int64
# ########################################

# %%
#fixing data type
df["cylinders"] = df.cylinders.astype(float)

# %%
#null değerlere bakılacak

# %% [markdown]
# ### weight column

# %%
first_look("weight")
# Out:
# column name :  weight
# --------------------------------
# Per_of_Nulls   :  % 43.81
# Num_of_Nulls   :  6974
# Num_of_Uniques :  434
# Value_counts :
#  NaN         6974
# 1,163 kg     574
# 1,360 kg     356
# 1,165 kg     301
# 1,335 kg     242
#             ...
# 1,960 kg       1
# 1,258 kg       1
# 1,167 kg       1
# 1,331 kg       1
# 2,037 kg       1
# Name: weight, Length: 435, dtype: int64
#
# Value_counts with sort index :
#  1 kg           2
# 1,009 kg       1
# 1,010 kg       3
# 1,017 kg       1
# 1,030 kg       1
#             ...
# 840 kg         1
# 900 kg         1
# 977 kg         2
# 980 kg        11
# NaN         6974
# Name: weight, Length: 435, dtype: int64
# ########################################

# %%
df["weight"] = df.weight.str.replace(",","").str.extract(r"(\d+)").astype(float)

# %%
#drop weight column
df.rename(columns={"weight":"weight_kg"},inplace=True)

# %%
df.weight_kg.isnull().sum()
# Out:
# 6974

# %% [markdown]
# ### drive_chain column

# %%
first_look("drive_chain")
# Out:
# column name :  drive_chain
# --------------------------------
# Per_of_Nulls   :  % 43.08
# Num_of_Nulls   :  6858
# Num_of_Uniques :  3
# Value_counts :
#  front    8886
# NaN      6858
# 4WD       171
# rear        4
# Name: drive_chain, dtype: int64
#
# Value_counts with sort index :
#  4WD       171
# front    8886
# rear        4
# NaN      6858
# Name: drive_chain, dtype: int64
# ########################################

# %%
#null değerlere bakılacak

# %% [markdown]
# ### fuel column

# %%
first_look("fuel")
# Out:
# column name :  fuel
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  77
# Value_counts :
#  Diesel (Particulate Filter)                                                                                                       4315
# Super 95                                                                                                                          3338
# Gasoline                                                                                                                          3175
# Diesel                                                                                                                            2984
# Super 95 / Regular/Benzine 91                                                                                                      424
# Regular/Benzine 91                                                                                                                 354
# ...

# %%
get_diff_category_column(df.fuel)
# Out:
# {0: 'Biodiesel',
#  1: 'Biogas',
#  2: 'CNG',
#  3: 'CNG (Particulate Filter)',
#  4: 'Diesel',
#  5: 'Diesel (Particulate Filter)',
#  6: 'Domestic gas H',
#  7: 'Electric',
#  8: 'Electric/Gasoline',
#  9: 'Gasoline',
#  10: 'Gasoline (Particulate Filter)',
#  11: 'LPG',
#  12: 'Liquid petroleum gas (LPG)',
#  13: 'Others',
#  14: 'Others (Particulate Filter)',
#  15: 'Regular/Benzine 91',
#  16: 'Regular/Benzine 91 (Particulate Filter)',
#  17: 'Regular/Benzine E10 91',
#  18: 'Regular/Benzine E10 91 (Particulate Filter)',
#  19: 'Super 95',
#  20: 'Super 95 (Particulate Filter)',
#  21: 'Super E10 95',
#  22: 'Super E10 95 (Particulate Filter)',
#  23: 'Super Plus 98',
#  24: 'Super Plus 98 (Particulate Filter)',
#  25: 'Super Plus E10 98',
#  26: 'Super Plus E10 98 (Particulate Filter)'}

# %%
#df.groupby("fuel").price.mean()  #yakıt farklılıklrının price etkisi var mı?

# %%
df.fuel.value_counts()
# Out:
# Diesel (Particulate Filter)                                                                                                       4315
# Super 95                                                                                                                          3338
# Gasoline                                                                                                                          3175
# Diesel                                                                                                                            2984
# Super 95 / Regular/Benzine 91                                                                                                      424
# Regular/Benzine 91                                                                                                                 354
# Super E10 95                                                                                                                       331
# ...

# %%
lpg = ["lpg", "CNG", "Domestic gas H", "Biogas"]
diesel = ["Diesel", "Biodiesel"]
benzine =["Gasoline", "Benzine", "Regular", "Super", "Other"]
electric_hybride = ["Electric"]

# %%
# Defining a function to categorize fuel column

def fuelcategory(row) :
    if any(x in row for x in lpg):
        return "LPG/CNG"
    elif any(x in row for x in electric_hybride) :
        return "Electric/Hybride"
    elif any(x in row for x in diesel) :
        if "Particulate Filter" in row :
            return "Diesel (Particulate Filter)"
        else :
            return "Diesel"
    else :
        if "Particulate Filter" in row :
            return "Benzine (Particulate Filter)"
        else :
            return "Benzine"

# %%
df["fuel"] = df.fuel.apply(fuelcategory)

# %%
df.fuel
# Out:
# 0         Diesel (Particulate Filter)
# 1                             Benzine
# 2         Diesel (Particulate Filter)
# 3         Diesel (Particulate Filter)
# 4         Diesel (Particulate Filter)
#                      ...
# 15914     Diesel (Particulate Filter)
# 15915    Benzine (Particulate Filter)
# 15916                          Diesel
# 15917                          Diesel
# 15918                         Benzine
# Name: fuel, Length: 15919, dtype: object

# %% [markdown]
# ### consumption column

# %%
first_look("consumption")
# Out:
# column name :  consumption
# --------------------------------
# Per_of_Nulls   :  % 11.97
# Num_of_Nulls   :  1906
# Num_of_Uniques :  881
# Value_counts :
#  NaN                                                                           1906
# ['3.9 l/100 km (comb)'],['4.1 l/100 km (city)'],['3.7 l/100 km (country)']     304
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']       276
# ['5.4 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.5 l/100 km (country)']     257
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']     253
#                                                                               ...
# ['4.2 l/100 km (comb)'],['5.3 l/100 km (city)'],['3.6 l/100 km (country)']       1
# 5.1 l/100 km (comb)6.4 l/100 km (city)4.3 l/100 km (country)                     1
# ['4.6 l/100 km (comb)'],['5.4 l/100 km (city)'],['6.7 l/100 km (country)']       1
# ...

# %%
df['consumption'].head(3)
# Out:
# 0    ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# 1    ['5.6 l/100 km (comb)'],['7.1 l/100 km (city)'],['4.7 l/100 km (country)']
# 2    ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# Name: consumption, dtype: object

# %%
# consumption sütunu temizlendi ve yakıt   tüketim değerleri ayrı kolonlara alındı
# yeni  consumption değerleri ve typelarının değişimi

df["consumption"]=df["consumption"].str.replace("[\[\]']?","")
df["consumption_comb"] = df.consumption.str.extract(r"(\d*\.\d+|\d+).+\(comb\)").astype(float)
df["consumption_city"] = df.consumption.str.extract(r"[.+]?,(\d*\.\d+|\d+).+\(city\)").astype(float)
df["consumption_country"] = df.consumption.str.extract(r".+,(\d*\.\d+|\d+).+\(country\)").astype(float)

# %%
df[["consumption","consumption_comb","consumption_city","consumption_country"]].sample(10)
# Out:
#                                                           consumption  \
# 15825  7.6 l/100 km (comb),9.9 l/100 km (city),6.4 l/100 km (country)
# 3774   3.9 l/100 km (comb),4.5 l/100 km (city),3.7 l/100 km (country)
# 1779   4.4 l/100 km (comb),5.2 l/100 km (city),3.9 l/100 km (country)
# 14767    5 l/100 km (comb),6.3 l/100 km (city),4.2 l/100 km (country)
# 8484   5.9 l/100 km (comb),7.9 l/100 km (city),4.8 l/100 km (country)
# 13852                                                             NaN
# 2618                                                              NaN
# 9980   6.6 l/100 km (comb),8.2 l/100 km (city),5.7 l/100 km (country)
# 15235    4.6 l/100 km (comb),5 l/100 km (city),4.4 l/100 km (country)
# 12105                                                             NaN
#
#        consumption_comb  consumption_city  consumption_country
# 15825               7.6               9.9                  6.4
# 3774                3.9               4.5                  3.7
# ...

# %%
# Checking the number of null values in new columns

df[["consumption_comb","consumption_city","consumption_country"]].isnull().sum()
# Out:
# consumption_comb       2033
# consumption_city       3272
# consumption_country    3212
# dtype: int64

# %%
df[["consumption_comb", "consumption_city", "consumption_country"]].notna().sum()
# Out:
# consumption_comb       13886
# consumption_city       12647
# consumption_country    12707
# dtype: int64

# %%
df[['consumption_comb', 'consumption_city', 'consumption_country']]
# Out:
#        consumption_comb  consumption_city  consumption_country
# 0                   3.8               4.3                  3.5
# 1                   5.6               7.1                  4.7
# 2                   3.8               4.4                  3.4
# 3                   3.8               4.3                  3.5
# 4                   4.1               4.6                  3.8
# ...                 ...               ...                  ...
# 15914               5.3               6.2                  4.7
# 15915               7.4               NaN                  NaN
# 15916               5.3               6.2                  4.7
# 15917               5.3               6.2                  4.7
# 15918               6.8               8.7                  5.7
#
# [15919 rows x 3 columns]

# %%
df.drop(columns="consumption",inplace=True)

# %%
df.shape
# Out:
# (15919, 45)

# %% [markdown]
# ### co_2_emission

# %%
first_look("co_2_emission")
# Out:
# column name :  co_2_emission
# --------------------------------
# Per_of_Nulls   :  % 15.3
# Num_of_Nulls   :  2436
# Num_of_Uniques :  122
# Value_counts :
#  NaN                      2436
# 120 g CO2/km (comb)       740
# 99 g CO2/km (comb)        545
# 97 g CO2/km (comb)        537
# 104 g CO2/km (comb)       501
#                          ...
# 14 g CO2/km (comb)          1
# 1,060 g CO2/km (comb)       1
# 51 g CO2/km (comb)          1
# 165 g CO2/km (comb)         1
# 193 g CO2/km (comb)         1
# Name: co_2_emission, Length: 123, dtype: int64
#
# Value_counts with sort index :
#  0 g CO2/km (comb)           2
# 1 g CO2/km (comb)           1
# 1,060 g CO2/km (comb)       1
# 100 g CO2/km (comb)        36
# 101 g CO2/km (comb)       105
#                          ...
# 97 g CO2/km (comb)        537
# 98 g CO2/km (comb)        151
# 99 g CO2/km (comb)        545
# 990 g CO2/km (comb)         1
# NaN                      2436
# Name: co_2_emission, Length: 123, dtype: int64
# ...

# %%
 df["co_2_emission"] = df.co_2_emission.str.replace(",", "").str.extract(r"(\d+)").astype(float)

# %%
 df["co_2_emission"]
# Out:
# 0         99.0
# 1        129.0
# 2         99.0
# 3         99.0
# 4        109.0
#          ...
# 15914    139.0
# 15915    168.0
# 15916    139.0
# 15917    139.0
# 15918    153.0
# Name: co_2_emission, Length: 15919, dtype: float64

# %%
#null değerlere bakılacak

# %% [markdown]
# ### emission_class column

# %%
first_look("emission_class")
# Out:
# column name :  emission_class
# --------------------------------
# Per_of_Nulls   :  % 22.79
# Num_of_Nulls   :  3628
# Num_of_Uniques :  6
# Value_counts :
#  Euro 6          10139
# NaN              3628
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             40
# Name: emission_class, dtype: int64
#
# Value_counts with sort index :
#  Euro 4             40
# Euro 5             78
# Euro 6          10139
# Euro 6c           127
# Euro 6d            62
# Euro 6d-TEMP     1845
# NaN              3628
# Name: emission_class, dtype: int64
# ########################################

# %%
#nullara bakılck

# %% [markdown]
# ### comfort_&_convenience column

# %%
first_look("comfort_&_convenience")
# Out:
# column name :  comfort_&_convenience
# --------------------------------
# Per_of_Nulls   :  % 5.78
# Num_of_Nulls   :  920
# Num_of_Uniques :  6198
# Value_counts :
#  NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  920
# ...

# %%
get_diff_category_column(df["comfort_&_convenience"])
# Out:
# {0: 'Air conditioning',
#  1: 'Air suspensio',
#  2: 'Armrest',
#  3: 'Automatic climate control',
#  4: 'Auxiliary heating',
#  5: 'Cruise control',
#  6: 'Electric Starter',
#  7: 'Electric tailgate',
#  8: 'Electrical side mirrors',
#  9: 'Electrically adjustable seats',
#  10: 'Electrically heated windshield',
#  11: 'Heads-up display',
#  12: 'Heated steering wheel',
#  13: 'Hill Holder',
#  14: 'Keyless central door lock',
#  15: 'Leather seats',
#  16: 'Leather steering wheel',
#  17: 'Light sensor',
#  18: 'Lumbar support',
#  19: 'Massage seats',
#  20: 'Multi-function steering wheel',
#  21: 'Navigation system',
#  22: 'Panorama roof',
#  23: 'Park Distance Control',
#  24: 'Parking assist system camera',
#  25: 'Parking assist system self-steering',
#  26: 'Parking assist system sensors front',
#  27: 'Parking assist system sensors rear',
#  28: 'Power windows',
#  29: 'Rain sensor',
#  30: 'Seat heating',
#  31: 'Seat ventilatio',
#  32: 'Split rear seats',
# ...

# %%
df.rename(columns={"comfort_&_convenience":"comfort_convenience"},inplace=True)

# %% [markdown]
# ### entertainment_&_media column

# %%
first_look("entertainment_&_media")
# Out:
# column name :  entertainment_&_media
# --------------------------------
# Per_of_Nulls   :  % 8.63
# Num_of_Nulls   :  1374
# Num_of_Uniques :  346
# Value_counts :
#  NaN                                                                                                 1374
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                                          1282
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                                       982
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB                             783
# On-board computer,Radio                                                                              487
#                                                                                                     ...
# Bluetooth,CD player,Digital radio,Hands-free equipment,Radio                                           1
# ...

# %%
get_diff_category_column(df["entertainment_&_media"])
# Out:
# {0: 'Bluetooth',
#  1: 'CD player',
#  2: 'Digital radio',
#  3: 'Hands-free equipment',
#  4: 'MP3',
#  5: 'On-board computer',
#  6: 'Radio',
#  7: 'Sound system',
#  8: 'Televisio',
#  9: 'USB'}

# %%
df.rename(columns={"entertainment_&_media":"entertainment_media"},inplace=True)

# %%
## nullara bakılcak

# %% [markdown]
# ### extras column

# %%
first_look("extras")
# Out:
# column name :  extras
# --------------------------------
# Per_of_Nulls   :  % 18.61
# Num_of_Nulls   :  2962
# Num_of_Uniques :  659
# Value_counts :
#  Alloy wheels                                                                                               3245
# NaN                                                                                                        2962
# Alloy wheels,Touch screen                                                                                   697
# Alloy wheels,Voice Control                                                                                  577
# Alloy wheels,Touch screen,Voice Control                                                                     541
#                                                                                                            ...
# Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control       1
# ...

# %%
get_diff_category_column(df["extras"])
# Out:
# {0: 'Alloy wheels',
#  1: 'Cab or rented Car',
#  2: 'Catalytic Converter',
#  3: 'Handicapped enabled',
#  4: 'Right hand drive',
#  5: 'Roof rack',
#  6: 'Shift paddles',
#  7: 'Ski bag',
#  8: 'Sliding door',
#  9: 'Sport package',
#  10: 'Sport seats',
#  11: 'Sport suspensio',
#  12: 'Touch scree',
#  13: 'Trailer hitch',
#  14: 'Tuned car',
#  15: 'Voice Control',
#  16: 'Winter tyres'}

# %%
# nullara bakılacak

# %% [markdown]
# ### safety_&_security

# %%
first_look("safety_&_security")
# Out:
# column name :  safety_&_security
# --------------------------------
# Per_of_Nulls   :  % 6.17
# Num_of_Nulls   :  982
# Num_of_Uniques :  4443
# Value_counts :
#  NaN                                                                                                                                                                                                                                                                                                                                                               982
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                      538
# ...

# %%
get_diff_category_column(df["safety_&_security"])
# Out:
# {0: 'ABS',
#  1: 'Adaptive Cruise Control',
#  2: 'Adaptive headlights',
#  3: 'Alarm system',
#  4: 'Blind spot monitor',
#  5: 'Central door lock',
#  6: 'Central door lock with remote control',
#  7: 'Daytime running lights',
#  8: 'Driver drowsiness detectio',
#  9: 'Driver-side airbag',
#  10: 'Electronic stability control',
#  11: 'Emergency brake assistant',
#  12: 'Emergency system',
#  13: 'Fog lights',
#  14: 'Head airbag',
#  15: 'Immobilizer',
#  16: 'Isofix',
#  17: 'LED Daytime Running Lights',
#  18: 'LED Headlights',
#  19: 'Lane departure warning system',
#  20: 'Night view assist',
#  21: 'Passenger-side airbag',
#  22: 'Power steering',
#  23: 'Rear airbag',
#  24: 'Side airbag',
#  25: 'Tire pressure monitoring system',
#  26: 'Traction control',
#  27: 'Traffic sign recognitio',
#  28: 'Xenon headlights'}

# %%
df.rename(columns={"safety_&_security":"safety_security"},inplace=True)

# %%
# nullara bakılacak

# %% [markdown]
# ### description column

# %%
first_look("description")
# Out:
# column name :  description
# --------------------------------
# Per_of_Nulls   :  % 4.19
# Num_of_Nulls   :  667
# Num_of_Uniques :  12863
# Value_counts :
# ...

# %%
df.drop(columns="description",inplace=True)

# %%
df.shape #shape()
# Out:
# (15919, 44)

# %% [markdown]
# ### emission_label column

# %%
first_look("emission_label")
# Out:
# column name :  emission_label
# --------------------------------
# Per_of_Nulls   :  % 75.22
# Num_of_Nulls   :  11974
# Num_of_Uniques :  5
# Value_counts :
#  NaN               11974
# 4 (Green)          3553
# 1 (No sticker)      381
# 5 (Blue)              8
# 3 (Yellow)            2
# 2 (Red)               1
# Name: emission_label, dtype: int64
#
# Value_counts with sort index :
#  1 (No sticker)      381
# 2 (Red)               1
# 3 (Yellow)            2
# 4 (Green)          3553
# 5 (Blue)              8
# NaN               11974
# Name: emission_label, dtype: int64
# ########################################

# %%
#diğer ilişkili kolonlarla karşılaştırılıp düşülecek

# %% [markdown]
# ### gears column

# %%
first_look("gears")
# Out:
# column name :  gears
# --------------------------------
# Per_of_Nulls   :  % 29.6
# Num_of_Nulls   :  4712
# Num_of_Uniques :  10
# Value_counts :
#  6      5822
# NaN    4712
# 5      3239
# 7      1908
# 8       224
# 9         6
# 1         2
# 3         2
# 4         2
# 2         1
# 50        1
# Name: gears, dtype: int64
#
# Value_counts with sort index :
#  1         2
# 2         1
# 3         2
# 4         2
# 5      3239
# 50        1
# 6      5822
# 7      1908
# 8       224
# 9         6
# NaN    4712
# Name: gears, dtype: int64
# ########################################

# %%
df["gears"]=df.gears.astype(float)

# %% [markdown]
# ### country_version column

# %%
first_look("country_version")
# Out:
# column name :  country_version
# --------------------------------
# Per_of_Nulls   :  % 52.35
# Num_of_Nulls   :  8333
# Num_of_Uniques :  23
# Value_counts :
#  NaN               8333
# Germany           4502
# Italy             1038
# European Union     507
# Netherlands        464
# Spain              325
# Belgium            314
# Austria            208
# Czech Republic      52
# Poland              49
# France              38
# Denmark             33
# Hungary             28
# Japan                8
# Slovakia             4
# Croatia              4
# Sweden               3
# Romania              2
# Bulgaria             2
# Luxembourg           1
# Switzerland          1
# Slovenia             1
# Egypt                1
# Serbia               1
# Name: country_version, dtype: int64
#
# Value_counts with sort index :
#  Austria            208
# Belgium            314
# Bulgaria             2
# Croatia              4
# Czech Republic      52
# Denmark             33
# ...

# %%
df.drop(columns="country_version",inplace=True)

# %%
df.shape
# Out:
# (15919, 43)

# %% [markdown]
# ## Saving cleaned df as "scout_car_part_1.csv"

# %%
df.to_csv('scout_car_part_1.csv', index=False)

# %%
pd.read_csv('scout_car_part_1.csv')
# Out:
#                                                                                    url  \
# 0      https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon...
# 1      https://www.autoscout24.com//offers/audi-a1-1-8-tfsi-sport-gasoline-red-b254...
# 2      https://www.autoscout24.com//offers/audi-a1-sportback-1-6-tdi-s-tronic-einpa...
# 3      https://www.autoscout24.com//offers/audi-a1-1-4-tdi-design-s-tronic-diesel-b...
# 4      https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-s-lin...
# ...                                                                                ...
# 15914  https://www.autoscout24.com//offers/renault-espace-blue-dci-200cv-edc-execut...
# 15915  https://www.autoscout24.com//offers/renault-espace-tce-225-edc-gpf-lim-delux...
# 15916  https://www.autoscout24.com//offers/renault-espace-blue-dci-200-edc-initiale...
# 15917  https://www.autoscout24.com//offers/renault-espace-blue-dci-200cv-edc-busine...
# ...
